# %% [markdown]
# ### Saving Figures
# [Ultimate Roadmap →](https://niveshbansal07.github.io/Matplotlib-Roadmap-2-Day-Beginner-to-Master-Python-Data-Visualization-Guide/)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y, label='Sine Wave')
ax.set_title("Saving Figures Example")
ax.legend()

# Adjust layout to avoid cut-off labels
fig.tight_layout()

# Save as PNG (300 DPI = High Quality)
fig.savefig('plot.png', dpi=300, bbox_inches='tight')

# Save as PDF (Vector Format, scalable without losing quality)
fig.savefig('plot.pdf', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# - fig.tight_layout() → Adjusts spacing automatically so labels/titles aren't cut off.
#
# - fig.savefig('filename.png', dpi=300) → Saves high-quality image.
#
# - bbox_inches='tight' → Trims extra white space around the figure.
#
# - dpi=300 → Professional print quality.
