# %% [markdown]
# ### Images & Heatmaps
# [Ultimate Roadmap →](https://niveshbansal07.github.io/Matplotlib-Roadmap-2-Day-Beginner-to-Master-Python-Data-Visualization-Guide/)

# %% [markdown]
# - Used to visualize 2D data (grids, images, intensity maps).

# %%
import numpy as np
import matplotlib.pyplot as plt

x = y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.exp(-(X**2  + Y**2))

fig, ax = plt.subplots()
im = ax.imshow(Z, extent=[-3, 3, -3, 3], origin='lower', cmap='magma')

ax.contour(X, Y, Z, colors='white')

fig.colorbar(im, ax=ax)
ax.set_title("Heatmap with Contours")
plt.show()

# %% [markdown]
# - Show 2D Data as Image
#
# <code>im = ax.imshow(A, aspect='auto', interpolation='nearest')</code>
#
# - Heatmap with Color Mesh
#
# <code> ax.pcolormesh(X, Y, Z) </code>
#
# - Contours (Lines of Equal Value)
#
# <code> ax.contour(X, Y, Z)     # Only lines <br>
# ax.contourf(X, Y, Z)    # Filled areas </code>
